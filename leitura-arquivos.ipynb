# %%
import pandas as pd

dadosPerson = pd.read_csv('Person.Person.csv', on_bad_lines='skip', sep=';')

dadosPerson.fillna("(não indentificado)", inplace=True)
dadosPerson.rename(columns={'rowguid': 'Rowguid'}, inplace=True)

# %%
dadosPerson
# Out:
#        BusinessEntityID PersonType  NameStyle                Title FirstName  \
# 0                     1         EM          0  (não indentificado)       Ken
# 1                     2         EM          0  (não indentificado)     Terri
# 2                     3         EM          0  (não indentificado)   Roberto
# 3                     4         EM          0  (não indentificado)       Rob
# 4                     5         EM          0                  Ms.      Gail
# ...                 ...        ...        ...                  ...       ...
# 19967             20773         IN          0  (não indentificado)   Crystal
# 19968             20774         IN          0  (não indentificado)  Isabella
# 19969             20775         IN          0  (não indentificado)   Crystal
# 19970             20776         IN          0  (não indentificado)   Crystal
# 19971             20777         IN          0  (não indentificado)   Crystal
#
# ...

# %%
dadosProduction = pd.read_csv('Production.Product.csv', on_bad_lines='skip', sep=';')
dadosProduction


dadosProduction.fillna("(não indentificado)", inplace=True)
dadosProduction.rename(columns={'rowguid': 'Rowguid'}, inplace=True)
dadosProduction
# Out:
# C:\Users\leand\AppData\Local\Temp\ipykernel_7764\3714453317.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '(não indentificado)' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   dadosProduction.fillna("(não indentificado)", inplace=True)
#      ProductID                   Name ProductNumber  MakeFlag  \
# 0            1        Adjustable Race       AR-5381         0
# 1            2           Bearing Ball       BA-8327         0
# 2            3        BB Ball Bearing       BE-2349         1
# 3            4  Headset Ball Bearings       BE-2908         0
# 4          316                  Blade       BL-2036         1
# ..         ...                    ...           ...       ...
# 499        995      ML Bottom Bracket       BB-8107         1
# 500        996      HL Bottom Bracket       BB-9108         1
# ...

# %%
dadosDetail = pd.read_csv('Sales.SalesOrderDetail.csv', on_bad_lines='skip', sep=';')
dadosDetail


dadosDetail.fillna("(não indentificado)", inplace=True)
dadosDetail.rename(columns={'rowguid': 'Rowguid'}, inplace=True)
dadosDetail
# Out:
#         SalesOrderID  SalesOrderDetailID CarrierTrackingNumber  OrderQty  \
# 0              43659                   1          4911-403C-98         1
# 1              43659                   2          4911-403C-98         3
# 2              43659                   3          4911-403C-98         1
# 3              43659                   4          4911-403C-98         1
# 4              43659                   5          4911-403C-98         1
# ...              ...                 ...                   ...       ...
# 121312         75122              121313   (não indentificado)         1
# 121313         75122              121314   (não indentificado)         1
# 121314         75123              121315   (não indentificado)         1
# 121315         75123              121316   (não indentificado)         1
# 121316         75123              121317   (não indentificado)         1
#
#         ProductID  SpecialOfferID UnitPrice UnitPriceDiscount  LineTotal  \
# ...

# %%
dadosHeader = pd.read_csv('Sales.SalesOrderHeader.csv', on_bad_lines='skip', sep=';')
dadosHeader


dadosHeader.fillna("(não indentificado)", inplace=True)
dadosHeader.rename(columns={'rowguid': 'Rowguid'}, inplace=True)
dadosHeader
# Out:
# C:\Users\leand\AppData\Local\Temp\ipykernel_7764\575520220.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '(não indentificado)' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   dadosHeader.fillna("(não indentificado)", inplace=True)
#        SalesOrderID  RevisionNumber                OrderDate  \
# 0             43659               8  2011-05-31 00:00:00.000
# 1             43660               8  2011-05-31 00:00:00.000
# 2             43661               8  2011-05-31 00:00:00.000
# 3             43662               8  2011-05-31 00:00:00.000
# 4             43663               8  2011-05-31 00:00:00.000
# ...             ...             ...                      ...
# 31460         75119               8  2014-06-30 00:00:00.000
# 31461         75120               8  2014-06-30 00:00:00.000
# 31462         75121               8  2014-06-30 00:00:00.000
# ...

# %%
dadosSpecial = pd.read_csv('Sales.SpecialOfferProduct.csv', on_bad_lines='skip', sep=';')
dadosSpecial



dadosSpecial.rename(columns={'rowguid': 'Rowguid'}, inplace=True)
dadosSpecial
# Out:
#      SpecialOfferID  ProductID                               Rowguid  \
# 0                 1        680  BB30B868-D86C-4557-8DB2-4B2D0A83A0FB
# 1                 1        706  B3C9A4B1-2AE6-4CBA-B552-1F206C9F4C1F
# 2                 1        707  27B711FE-0B77-4EA4-AD1A-7C239956BEF4
# 3                 1        708  46CBB78B-246E-4D69-9BD6-E521277C1078
# 4                 1        709  CF102AA0-055F-4D2B-8B98-04B161758EA8
# ..              ...        ...                                   ...
# 533              16        984  52DD0F65-0EA9-4848-9884-7594BA953274
# 534              16        985  C8127A82-05C3-42FD-A5C6-215D58A236BD
# 535              16        986  C60FB28D-2431-481C-985E-3FEA8119D705
# 536              16        987  BEBD6F20-D6C2-4511-8C97-1F53B2099D1F
# 537              16        988  2981C98B-A18F-4153-A6A2-EC453CB130CE
#
#                 ModifiedDate
# 0    2011-04-01 00:00:00.000
# 1    2011-04-01 00:00:00.000
# 2    2011-04-01 00:00:00.000
# ...
